# %% [markdown]
# # Class-weighted Learning
# - Class-imbalance problem is actually a quite common problem. For instance, there are much more purchasers among mobile app users and much more non-criminals than criminals in society.
# - However, if class imbalance is too severe (i.e., training set is highly skewed), it is likely to  bear undesirable effects.
#     - For instance, algorithm will tend to vote for majority class, all the time.
#     - This is highly risky since we might lose track of purchasers among mobile app users and criminals, which are relatively rare among training instances

# %%
import numpy as np
from sklearn.utils import class_weight
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.metrics import *
from collections import Counter
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ## Load Dataset
# - Breast cancer dataset in ```sklearn```
# - doc: http://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_breast_cancer.html

# %%
data = load_breast_cancer()
X_data = data.data.tolist()
y_data = data.target.tolist()

# %%
print("Number of malignant instances (0): ", Counter(y_data)[0])
print("Number of benign instances (1): ", Counter(y_data)[1])
# Out:
# Number of malignant instances (0):  212
# Number of benign instances (1):  357

# %%
# delete some of malignant instances to generate class-imbalance situation artificially
for i in range(200):
    if y_data[i] == 0:
        X_data[i] = None
        y_data[i] = None

# %%
X_data = [x for x in X_data if x != None]
y_data = [y for y in y_data if y != None]

# %%
print("Number of malignant instances (0): ", Counter(y_data)[0])
print("Number of benign instances (1): ", Counter(y_data)[1])
# Out:
# Number of malignant instances (0):  108
# Number of benign instances (1):  357

# %%
X_train, X_test, y_train, y_test = train_test_split(np.asarray(X_data), np.asarray(y_data), test_size = 0.2, random_state = 7) 

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (372, 30) (93, 30) (372,) (93,)

# %% [markdown]
# ## Computing class weights
# - We compute class weights based on training dataset, and deliver as parameter when fitting

# %%
weights = class_weight.compute_class_weight('balanced', np.unique(y_train), y_train)

# %%
class_weights = dict(zip(np.unique(y_train), weights))
print("Computed class weights: ", class_weights)
# Out:
# Computed class weights:  {0: 2.2409638554216866, 1: 0.643598615916955}

# %% [markdown]
# ## Naive Learning

# %%
def simple_mlp():
    model = Sequential()
    model.add(Dense(10, input_shape = (X_train.shape[1],), activation = 'relu'))
    model.add(Dense(1, activation = 'sigmoid'))
    model.compile(optimizer = Adam(lr = 0.001), loss = 'binary_crossentropy', metrics = ['accuracy'])
    return model

# %%
model = simple_mlp()
model.fit(X_train, y_train, epochs = 50)
# Out:
# Epoch 1/50
# 12/12 [==============================] - 0s 1ms/step - loss: 17.7471 - accuracy: 0.2177
# Epoch 2/50
# 12/12 [==============================] - 0s 1ms/step - loss: 4.3875 - accuracy: 0.6935
# Epoch 3/50
# 12/12 [==============================] - 0s 1ms/step - loss: 2.0329 - accuracy: 0.6263
# Epoch 4/50
# 12/12 [==============================] - 0s 1ms/step - loss: 1.3390 - accuracy: 0.7312
# Epoch 5/50
# 12/12 [==============================] - 0s 1ms/step - loss: 1.1139 - accuracy: 0.7796
# Epoch 6/50
# 12/12 [==============================] - 0s 1ms/step - loss: 0.9453 - accuracy: 0.8065
# Epoch 7/50
# 12/12 [==============================] - 0s 2ms/step - loss: 0.8840 - accuracy: 0.7823
# Epoch 8/50
# 12/12 [==============================] - 0s 1ms/step - loss: 0.8277 - accuracy: 0.8387
# Epoch 9/50
# 12/12 [==============================] - 0s 1ms/step - loss: 0.7852 - accuracy: 0.7903
# Epoch 10/50
# 12/12 [==============================] - 0s 1ms/step - loss: 0.7032 - accuracy: 0.8387
# Epoch 11/50
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6550 - accuracy: 0.8468
# Epoch 12/50
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6433 - accuracy: 0.8468
# Epoch 13/50
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6236 - accuracy: 0.8548
# Epoch 14/50
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5744 - accuracy: 0.8629
# Epoch 15/50
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5671 - accuracy: 0.8575
# Epoch 16/50
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5713 - accuracy: 0.8817
# Epoch 17/50
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5942 - accuracy: 0.8333
# Epoch 18/50
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5275 - accuracy: 0.9032
# Epoch 19/50
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5427 - accuracy: 0.8548
# Epoch 20/50
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4974 - accuracy: 0.8898
# Epoch 21/50
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4631 - accuracy: 0.8952
# Epoch 22/50
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4443 - accuracy: 0.8817
# Epoch 23/50
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4385 - accuracy: 0.9086
# Epoch 24/50
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4385 - accuracy: 0.8898
# Epoch 25/50
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4243 - accuracy: 0.8978
# Epoch 26/50
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4049 - accuracy: 0.8871
# Epoch 27/50
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3978 - accuracy: 0.8978
# Epoch 28/50
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3825 - accuracy: 0.8898
# Epoch 29/50
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3858 - accuracy: 0.9059
# Epoch 30/50
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3876 - accuracy: 0.9005
# Epoch 31/50
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3976 - accuracy: 0.9005
# Epoch 32/50
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3806 - accuracy: 0.9059
# Epoch 33/50
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3601 - accuracy: 0.9086
# Epoch 34/50
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3461 - accuracy: 0.9032
# Epoch 35/50
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3597 - accuracy: 0.9167
# Epoch 36/50
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3678 - accuracy: 0.9032
# Epoch 37/50
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3426 - accuracy: 0.9086
# Epoch 38/50
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3276 - accuracy: 0.9086
# Epoch 39/50
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3193 - accuracy: 0.9113
# Epoch 40/50
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3356 - accuracy: 0.9059
# Epoch 41/50
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3330 - accuracy: 0.9167
# Epoch 42/50
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3089 - accuracy: 0.9032
# Epoch 43/50
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3143 - accuracy: 0.9113
# Epoch 44/50
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3174 - accuracy: 0.9220
# Epoch 45/50
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3225 - accuracy: 0.9005
# Epoch 46/50
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3061 - accuracy: 0.9167
# Epoch 47/50
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2872 - accuracy: 0.9167
# Epoch 48/50
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3078 - accuracy: 0.9086
# Epoch 49/50
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3034 - accuracy: 0.9220
# Epoch 50/50
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2904 - accuracy: 0.9167

# %%
y_prob = model.predict(X_test)
y_pred = y_prob.round()

# %%
print("% of predicted 1's: ", y_pred.sum()/len(y_pred))
print("ROC AUC score: ", roc_auc_score(y_test, y_prob))
print("Overall Accuracy Score: ", accuracy_score(y_test, y_pred))
# Out:
# % of predicted 1's:  0.7526881720430108
# ROC AUC score:  0.9523529411764706
# Overall Accuracy Score:  0.9139784946236559

# %% [markdown]
# ## Class-weighted learning

# %%
model = simple_mlp()
model.fit(X_train, y_train, epochs = 50, class_weight = class_weights)
# Out:
# Epoch 1/50
# 12/12 [==============================] - 0s 2ms/step - loss: 13.5284 - accuracy: 0.2231
# Epoch 2/50
# 12/12 [==============================] - 0s 1ms/step - loss: 5.7684 - accuracy: 0.2231
# Epoch 3/50
# 12/12 [==============================] - 0s 1ms/step - loss: 1.5453 - accuracy: 0.5054
# Epoch 4/50
# 12/12 [==============================] - 0s 1ms/step - loss: 1.0283 - accuracy: 0.5672
# Epoch 5/50
# 12/12 [==============================] - 0s 1ms/step - loss: 0.7796 - accuracy: 0.2231
# Epoch 6/50
# 12/12 [==============================] - 0s 2ms/step - loss: 0.7075 - accuracy: 0.4382
# Epoch 7/50
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6559 - accuracy: 0.2285
# Epoch 8/50
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6533 - accuracy: 0.2312
# Epoch 9/50
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6351 - accuracy: 0.2204
# Epoch 10/50
# 12/12 [==============================] - 0s 1ms/step - loss: 0.6296 - accuracy: 0.3333
# Epoch 11/50
# 12/12 [==============================] - 0s 1ms/step - loss: 0.6311 - accuracy: 0.2258
# Epoch 12/50
# 12/12 [==============================] - 0s 1ms/step - loss: 0.6029 - accuracy: 0.3038
# Epoch 13/50
# 12/12 [==============================] - 0s 1ms/step - loss: 0.6101 - accuracy: 0.4785
# Epoch 14/50
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6111 - accuracy: 0.2849
# Epoch 15/50
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5899 - accuracy: 0.3414
# Epoch 16/50
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5896 - accuracy: 0.5699
# Epoch 17/50
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5680 - accuracy: 0.3360
# Epoch 18/50
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5628 - accuracy: 0.5699
# Epoch 19/50
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5519 - accuracy: 0.5134
# Epoch 20/50
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5425 - accuracy: 0.5914
# Epoch 21/50
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5346 - accuracy: 0.5349
# Epoch 22/50
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5463 - accuracy: 0.7419
# Epoch 23/50
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5525 - accuracy: 0.4731
# Epoch 24/50
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5188 - accuracy: 0.6774
# Epoch 25/50
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5143 - accuracy: 0.7554
# Epoch 26/50
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4987 - accuracy: 0.6371
# Epoch 27/50
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4988 - accuracy: 0.7446
# Epoch 28/50
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4874 - accuracy: 0.7608
# Epoch 29/50
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4806 - accuracy: 0.7581
# Epoch 30/50
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4779 - accuracy: 0.8011
# Epoch 31/50
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4798 - accuracy: 0.8306
# Epoch 32/50
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4709 - accuracy: 0.6344
# Epoch 33/50
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4540 - accuracy: 0.8522
# Epoch 34/50
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4461 - accuracy: 0.8306
# Epoch 35/50
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4454 - accuracy: 0.7957
# Epoch 36/50
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4403 - accuracy: 0.8548
# Epoch 37/50
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4349 - accuracy: 0.8441
# Epoch 38/50
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4209 - accuracy: 0.8306
# Epoch 39/50
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4148 - accuracy: 0.8683
# Epoch 40/50
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4147 - accuracy: 0.8763
# Epoch 41/50
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4058 - accuracy: 0.8360
# Epoch 42/50
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4089 - accuracy: 0.8548
# Epoch 43/50
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3845 - accuracy: 0.8871
# Epoch 44/50
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3839 - accuracy: 0.9086
# Epoch 45/50
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3816 - accuracy: 0.8495
# Epoch 46/50
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3820 - accuracy: 0.8683
# Epoch 47/50
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3651 - accuracy: 0.9032
# Epoch 48/50
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3593 - accuracy: 0.8952
# Epoch 49/50
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3837 - accuracy: 0.8817
# Epoch 50/50
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3543 - accuracy: 0.8548

# %%
y_prob = model.predict(X_test)
y_pred = y_prob.round()

# %%
print("% of predicted 1's: ", y_pred.sum()/len(y_pred))
print("ROC AUC score: ", roc_auc_score(y_test, y_prob))
print("Overall Accuracy Score: ", accuracy_score(y_test, y_pred))
# Out:
# % of predicted 1's:  0.7849462365591398
# ROC AUC score:  0.9311764705882354
# Overall Accuracy Score:  0.9032258064516129
