# %% [markdown]
# ## Using pretrained models
# - Keras Applications provided deep learning models with pre-trained weights
# - Documentation: https://keras.io/applications/

# %%
import numpy as np

from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.applications.resnet50 import preprocess_input, decode_predictions

# %% [markdown]
# ### Load image
# - Images can be loaded using load_img function

# %%
# img src = 'https://gfp-2a3tnpzj.stackpathdns.com/wp-content/uploads/2016/07/Dachshund-600x600.jpg'
img = load_img('dog.jpg')

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x600 at 0x2527E234BA8>

# %% [markdown]
# ### Import model
# - Currently, seven models are supported
#     - Xception
#     - VGG16
#     - VGG19
#     - ResNet50
#     - InceptionV3
#     - InceptionResNetV2
#     - MobileNet

# %%
from keras.applications.resnet50 import ResNet50
# Out:
# Using TensorFlow backend.

# %%
model = ResNet50(weights='imagenet')
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.2/resnet50_weights_tf_dim_ordering_tf_kernels.h5
# 102834176/102853048 [============================>.] - ETA: 0s

# %%
img = load_img('dog.jpg', target_size = (224, 224))    # image size can be calibrated with target_size parameter
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x1F37196E898>

# %%
img = img_to_array(img)
print(img.shape)
# Out:
# (224, 224, 3)

# %%
img = np.expand_dims(img, axis=0)
print(img.shape)
# Out:
# (1, 224, 224, 3)

# %%
## prediction wo preprocessing
pred_class = model.predict(img)
# print(pred_class)

# %%
# print only top 10 predicted classes
n = 10
top_n = decode_predictions(pred_class, top=n)

# %%
for c in top_n[0]:
    print(c)
# Out:
# ('n02099849', 'Chesapeake_Bay_retriever', 0.39825824)
# ('n02099712', 'Labrador_retriever', 0.24123101)
# ('n02088364', 'beagle', 0.071259342)
# ('n02105412', 'kelpie', 0.022412946)
# ('n02090379', 'redbone', 0.019160802)
# ('n02100236', 'German_short-haired_pointer', 0.018552378)
# ('n02092339', 'Weimaraner', 0.017511733)
# ('n02087394', 'Rhodesian_ridgeback', 0.015217513)
# ('n02093428', 'American_Staffordshire_terrier', 0.010090247)
# ('n02085620', 'Chihuahua', 0.0099846246)

# %%
img = preprocess_input(img)    # preprocess image with preprocess_input function
print(img.shape)
# Out:
# (1, 224, 224, 3)

# %%
## prediction with preprocessing
pred_class = model.predict(img)
# print(pred_class)

# %%
n = 10
top_n = decode_predictions(pred_class, top=n)

# %%
for c in top_n[0]:
    print(c)
# Out:
# ('n02106550', 'Rottweiler', 0.51168609)
# ('n02107142', 'Doberman', 0.18843709)
# ('n02107312', 'miniature_pinscher', 0.1246004)
# ('n02101006', 'Gordon_setter', 0.061222028)
# ('n02107908', 'Appenzeller', 0.025918268)
# ('n02112706', 'Brabancon_griffon', 0.02114767)
# ('n02089078', 'black-and-tan_coonhound', 0.014324501)
# ('n02085620', 'Chihuahua', 0.0033459149)
# ('n02096051', 'Airedale', 0.0032929969)
# ('n02087046', 'toy_terrier', 0.0031764628)
